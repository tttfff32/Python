# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("Z:\mora\פייתון מתקדם\שיעור 5\cc.csv")

# %%
df
# Out:
#      LatD   LatM  LatS    NS  LonD   LonM   LonS    EW                City  \
# 0      41      5    59   "N"    80     39      0   "W"        "Youngstown"
# 1      42     52    48   "N"    97     23     23   "W"           "Yankton"
# 2      46     35    59   "N"   120     30     36   "W"            "Yakima"
# 3      42     16    12   "N"    71     48      0   "W"         "Worcester"
# 4      43     37    48   "N"    89     46     11   "W"   "Wisconsin Dells"
# ..    ...    ...   ...   ...   ...    ...    ...   ...                 ...
# 123    39     31    12   "N"   119     48     35   "W"              "Reno"
# 124    50     25    11   "N"   104     39      0   "W"            "Regina"
# 125    40     10    48   "N"   122     14     23   "W"         "Red Bluff"
# 126    40     19    48   "N"    75     55     48   "W"           "Reading"
# 127    41      9    35   "N"    81     14     23   "W"           "Ravenna"
#
#     State
# 0      OH
# 1      SD
# 2      WA
# 3      MA
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.LatD = df.LatD.fillna(0)

# %%
df.drop_duplicates()
# Out:
#      LatD   LatM  LatS    NS  LonD   LonM   LonS    EW                City  \
# 0      41      5    59   "N"    80     39      0   "W"        "Youngstown"
# 1      42     52    48   "N"    97     23     23   "W"           "Yankton"
# 2      46     35    59   "N"   120     30     36   "W"            "Yakima"
# 3      42     16    12   "N"    71     48      0   "W"         "Worcester"
# 4      43     37    48   "N"    89     46     11   "W"   "Wisconsin Dells"
# ..    ...    ...   ...   ...   ...    ...    ...   ...                 ...
# 123    39     31    12   "N"   119     48     35   "W"              "Reno"
# 124    50     25    11   "N"   104     39      0   "W"            "Regina"
# 125    40     10    48   "N"   122     14     23   "W"         "Red Bluff"
# 126    40     19    48   "N"    75     55     48   "W"           "Reading"
# 127    41      9    35   "N"    81     14     23   "W"           "Ravenna"
#
#     State
# 0      OH
# 1      SD
# 2      WA
# 3      MA
# ...

# %%
min=df['LatD'].min()

# %%
min
# Out:
# 26

# %%
df.loc[min]
# Out:
# LatD                38
#  LatM               53
# LatS                23
# NS                 "N"
# LonD                77
#  LonM                1
#  LonS               47
#  EW                "W"
# City      "Washington"
# State               DC
# Name: 26, dtype: object

# %%
yachas= df['LatD']/df['LatS']

# %%
yachas
# Out:
# 0      0.694915
# 1      0.875000
# 2      0.779661
# 3      3.500000
# 4      0.895833
#          ...
# 123    3.250000
# 124    4.545455
# 125    0.833333
# 126    0.833333
# 127    1.171429
# Length: 128, dtype: float64

# %%
df.insert(5,"Populaon",yachas)

# %%
df
# Out:
#      LatD   LatM  LatS    NS  LonD  Populaon   LonM   LonS    EW  \
# 0      41      5    59   "N"    80  0.694915     39      0   "W"
# 1      42     52    48   "N"    97  0.875000     23     23   "W"
# 2      46     35    59   "N"   120  0.779661     30     36   "W"
# 3      42     16    12   "N"    71  3.500000     48      0   "W"
# 4      43     37    48   "N"    89  0.895833     46     11   "W"
# ..    ...    ...   ...   ...   ...       ...    ...    ...   ...
# 123    39     31    12   "N"   119  3.250000     48     35   "W"
# 124    50     25    11   "N"   104  4.545455     39      0   "W"
# 125    40     10    48   "N"   122  0.833333     14     23   "W"
# 126    40     19    48   "N"    75  0.833333     55     48   "W"
# 127    41      9    35   "N"    81  1.171429     14     23   "W"
#
#                    City State
# 0          "Youngstown"    OH
# 1             "Yankton"    SD
# 2              "Yakima"    WA
# 3           "Worcester"    MA
# ...

# %%
df['State']!="OH"
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 123    True
# 124    True
# 125    True
# 126    True
# 127    True
# Name: State, Length: 128, dtype: bool

# %%
df['LatD'].sort_values(ascending=False)
# Out:
# 124    50
# 33     49
# 6      49
# 10     48
# 54     47
#        ..
# 108    29
# 31     28
# 84     27
# 52     27
# 16     26
# Name: LatD, Length: 128, dtype: int64
